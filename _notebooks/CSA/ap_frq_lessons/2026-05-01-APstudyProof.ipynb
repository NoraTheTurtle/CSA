# %% [markdown]
# ---
# toc: true
# microblog: false
# assignment: false
# layout: post
# codemirror: true
# title: AP Study
# description: Proof of my AP studying
# courses: { csa: {week: 30} }
# permalink: /ApStudy
# show_sidebar: false
# ---

# %% [markdown]
# ### College Board MCQS

# %% [markdown]
# ![MCQs](images/practiceMCQs.png)

# %% [markdown]
# | Skill Code | Skill Name                                      | Personal Score (out of 10) |
# |------------|--------------------------------------------------|----------|
# | 2.A        | Determine code result (tracing)                 | 7/10 |
# | 2.B        | Write code (implement logic)                    | 6/10 |
# | 2.C        | Identify and correct errors                     | 8/10 |
# | 2.D        | Describe behavior of code                       | 9/10 |
# | 3.A        | Array traversal                                 | 7/10 |
# | 3.B        | Array algorithms                                | 7/10 |
# | 3.C        | Searching (linear search)                       | 8/10 |
# | 3.D        | Sorting (selection sort, etc.)                  | 7/10 |
# | 4.A        | 2D array traversal                              | 8/10 |
# | 4.B        | 2D array algorithms                             | 8/10 |
# | 4.C        | Matrix transformations / manipulation           | 8/10 |
# | 5.A        | Recursion: base cases                           | 8/10 |
# | 5.B        | Recursion: trace / determine result             | 7/10 |
# | 5.C        | Recursion: write / fix code                     | 7/10 |

# %% [markdown]
# ## Units/skills to review
#
# ### Unit 4 (data collection)
# Scores: 17/21, 16/21
#
# ### Unit 2 (selection/iteration)
# scores: 16/18, 17/21
#
# ### Skill 2B/5C (implement logic + write/fix code)
# (add the missing code)
#
# ### Skills 3A/5B (Array Transversal + Recursion trace)
# (go through elements in an array, read, modify, etc...)

# %% [markdown]
# ## Plan:
# Review college board videos coresponding to those units/skills + redo questions I got wrong on the practice and read the solutions

# %% [markdown]
# ---

# %% [markdown]
# ## College Board FRQs

# %% [markdown]
# ![Frqs](images/practiceFRQs.png)

# %% [markdown]
# ## Plan:
# 1. Review **Past years FRQS/compare my answers** to the answer key given
#
# 2. Study the **refrence page** given to familiarize myself with all functions/code it might ask me to write
#
# 3. Review **chief readers report** to see the grading of FRQS and what I should focus on to maximize points
#
# [Past years frqs + chief readers report](https://apcentral.collegeboard.org/courses/ap-computer-science-a/exam/past-exam-questions)
